# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(" #RIPKobe4.4.csv")
data.head()
# Out:
#                                                 text  Unnamed: 1  Unnamed: 2  \
# 0  Love you, Mamba. #RIPKobe https://t.co/5yOHhU8d7c         NaN         NaN
# 1  I'm watching Kobe's final game. I know exactly...         NaN         NaN
# 2  Watching Kobe's Farewell game and I'm still ge...         NaN         NaN
# 3  Bro, one thing about Kobe.....he ALWAYS had th...         NaN         NaN
# 4  Kobe, Duncan and Garnett what a HOF class!!! L...         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
text = data["text"]

# %%
text
# Out:
# 0      Love you, Mamba. #RIPKobe https://t.co/5yOHhU8d7c
# 1      I'm watching Kobe's final game. I know exactly...
# 2      Watching Kobe's Farewell game and I'm still ge...
# 3      Bro, one thing about Kobe.....he ALWAYS had th...
# 4      Kobe, Duncan and Garnett what a HOF class!!! L...
#                              ...
# 474    Ok #ripkobe ❤ but I'm sorry I'm picking #2 and...
# 475    I really miss Kobe man......... 💜💛 🐐 8 🐐 24 #N...
# 476    Just watched 3 random episodes of Deal and No ...
# 477    Nah fam, I hate it here. Fuck 2020. #WW3Scare ...
# 478    @KendrickPerkins @stephenasmith @Espngreeny Al...
# Name: text, Length: 479, dtype: object

# %%
import preprocessor as p

# %%
def preprocess_tweet(row):
    text = row['text']
    text = p.clean(text)
    return text

# %%
data['text'] = data.apply(preprocess_tweet, axis=1)

# %%
data.head()
# Out:
#                                                 text  Unnamed: 1  Unnamed: 2  \
# 0                                   Love you, Mamba.         NaN         NaN
# 1  I'm watching Kobe's final game. I know exactly...         NaN         NaN
# 2  Watching Kobe's Farewell game and I'm still ge...         NaN         NaN
# 3  Bro, one thing about Kobe.....he ALWAYS had th...         NaN         NaN
# 4  Kobe, Duncan and Garnett what a HOF class!!! L...         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
from gensim.parsing.preprocessing import remove_stopwords

# %%
def stopword_removal(row):
    text = row['text']
    text = remove_stopwords(text)
    return text

# %%
data['text'] = data.apply(stopword_removal, axis=1)

# %%
data.head()
# Out:
#                                                 text  Unnamed: 1  Unnamed: 2  \
# 0                                   Love you, Mamba.         NaN         NaN
# 1  I'm watching Kobe's final game. I know exactly...         NaN         NaN
# 2  Watching Kobe's Farewell game I'm getting chil...         NaN         NaN
# 3          Bro, thing Kobe.....he ALWAYS swag. Iykyk         NaN         NaN
# 4      Kobe, Duncan Garnett HOF class!!! Legends!! …         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
tweets = data['text']

# %%
tweets
# Out:
# 0                                       Love you, Mamba.
# 1      I'm watching Kobe's final game. I know exactly...
# 2      Watching Kobe's Farewell game I'm getting chil...
# 3              Bro, thing Kobe.....he ALWAYS swag. Iykyk
# 4          Kobe, Duncan Garnett HOF class!!! Legends!! …
#                              ...
# 474    Ok I'm sorry I'm picking kicking dumbass kanye...
# 475                             I miss Kobe man.........
# 476    Just watched random episodes Deal No Deal And ...
# 477                         Nah fam, I hate here. Fuck .
# 478    All said "reminds". Y'all act like brotha call...
# Name: text, Length: 479, dtype: object

# %%
tweets.to_csv ('KobeDataClean.csv', index = False, header=True)
